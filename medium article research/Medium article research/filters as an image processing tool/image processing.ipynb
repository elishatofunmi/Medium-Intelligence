# %%
import cv2
import numpy as np
import pandas as pd
import os, sys

# %%
os.chdir('/content/drive/My Drive/Medium article research/filters as an image processing tool')
current_dir = os.getcwd()
os.listdir()
# Out:
# ['image processing.ipynb', 'dog.jpeg']

# %% [markdown]
# # READ Image

# %%
import matplotlib.pyplot as plt
image = cv2.imread('dog.jpeg')
print("Shape: {}".format(image.shape))
plt.imshow(image)
# Out:
# Shape: (163, 310, 3)

# %% [markdown]
# # RGB IMAGE

# %%
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %% [markdown]
# # BGR IMAGE

# %%
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

plt.imshow(img)

# %% [markdown]
# # mean filter appication
